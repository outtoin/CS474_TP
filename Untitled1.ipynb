# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
with open ('test/results.txt', 'r') as f:
    result = f.readlines()

# %%
result = [line.split('\n')[0] for line in result]
results = [line.split(':') for line in result if line.split(':')[1] == ' Accuracy']

# %%
result[0].split(':')[1]
# Out:
# ' Accuracy'

# %%
results[0][0].split('/')[1]
# Out:
# 'taskA(1000,1,0.3).txt]'

# %%
taskA = np.array([line for line in results if 'taskA' in line[0].split('/')[1]])
taskB = np.array([line for line in results if 'taskB' in line[0].split('/')[1]])
taskC = np.array([line for line in results if 'taskC' in line[0].split('/')[1]])

# %%
taskA[:, 0] = list(map(lambda s: s[12:-6], taskA[:, 0]))
taskB[:, 0] = list(map(lambda s: s[12:-6], taskB[:, 0]))
taskC[:, 0] = list(map(lambda s: s[12:-6], taskC[:, 0]))

# %%
dfA = pd.DataFrame(taskA)
dfA = dfA.drop(1, axis=1)
dfA.columns = ['a', 'Accuracy']
df1 = pd.DataFrame(dfA.a.str.split(',').tolist(), columns=['num', 'k', 'roughness'])
dfA = pd.concat([df1, df.Accuracy], axis=1)
dfA = dfA.infer_objects()
dfA = dfA.apply(pd.to_numeric, errors='ignore')

# %%
dfB = pd.DataFrame(taskB)
dfB = dfB.drop(1, axis=1)
dfB.columns = ['a', 'Accuracy']
df1 = pd.DataFrame(dfB.a.str.split(',').tolist(), columns=['num', 'k', 'roughness'])
dfB = pd.concat([df1, dfB.Accuracy], axis=1)
dfB = dfB.apply(pd.to_numeric, errors='ignore')

# %%
dfA
# Out:
#     num   k  roughness  Accuracy
# 0  1000   1        0.3    0.4266
# 1  1000  10        0.3    0.4097
# 2  1000   3        0.3    0.4164
# 3  1000   5        0.3    0.3859
# 4   200  10        0.3    0.4106
# 5   200   3        0.3    0.3736
# 6   200   5        0.3    0.4137
# 7    50  10        0.3    0.4177
# 8    50   3        0.3    0.4386
# 9    50   5        0.3    0.3969

# %%
dfC = pd.DataFrame(taskC)
dfC = dfC.drop(1, axis=1)
dfC.columns = ['a', 'Accuracy']
df1 = pd.DataFrame(dfC.a.str.split(',').tolist(), columns=['num', 'k', 'roughness'])
dfC = pd.concat([df1, dfC.Accuracy], axis=1)
dfC = dfC.apply(pd.to_numeric, errors='ignore')

# %%
f, ax = plt.subplots(1, 1, figsize=(12, 8))
ax.set_ylim([0.2, 0.55])
plt.title('Accuracy at TaskA', fontsize=20)
plt.xlabel('SVQ size', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.xticks(rotation=90)
sns.pointplot(taskA[:, 0], taskA[:, 2].astype(np.float), linestyles=["-"])

# %%
dfA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
# num          10 non-null object
# k            10 non-null object
# roughness    10 non-null object
# Accuracy     10 non-null object
# dtypes: object(4)
# memory usage: 400.0+ bytes

# %%
f, ax = plt.subplots(1, 1, figsize=(12, 8))
ax.set_ylim([0.35, 0.45])
plt.title('Accuracy at TaskA', fontsize=20)
plt.xlabel('SVQ size', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.xticks(rotation=90)
plt.grid(True)
sns.pointplot(x='num', y='Accuracy', hue='k', data=dfA, palette='hls')

# %%
f, ax = plt.subplots(1, 1, figsize=(12, 8))
ax.set_ylim([0.65, 0.8])
plt.title('Accuracy at TaskB', fontsize=20)
plt.xlabel('SVQ size', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.xticks(rotation=90)
plt.grid(True)
sns.pointplot(x='num', y='Accuracy', hue='k', data=dfB, palette='hls')

# %%
f, ax = plt.subplots(1, 1, figsize=(12, 8))
ax.set_ylim([0.35, 0.45])
plt.title('Accuracy at TaskC', fontsize=20)
plt.xlabel('SVQ size', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.grid(True)
sns.pointplot(x='num', y='Accuracy', hue='k', data=dfC, palette='hls')

# %%
taskA
# Out:
# array([['taskA(1000,1,0.3)', ' Accuracy', '0.42660000920295715'],
#        ['taskA(1000,10,0.3)', ' Accuracy', '0.4097000062465668'],
#        ['taskA(1000,3,0.3)', ' Accuracy', '0.4163999855518341'],
#        ['taskA(1000,5,0.3)', ' Accuracy', '0.38589999079704285'],
#        ['taskA(200,10,0.3)', ' Accuracy', '0.4106000065803528'],
#        ['taskA(200,3,0.3)', ' Accuracy', '0.3736000061035156'],
#        ['taskA(200,5,0.3)', ' Accuracy', '0.41370001435279846'],
#        ['taskA(50,10,0.3)', ' Accuracy', '0.41769999265670776'],
#        ['taskA(50,3,0.3)', ' Accuracy', '0.43860000371932983'],
#        ['taskA(50,5,0.3)', ' Accuracy', '0.3968999981880188']],
#       dtype='<U29')

# %%
dfB
# Out:
#     num   k  roughness  Accuracy
# 0  1000   1        0.3    0.7268
# 1  1000  10        0.3    0.7253
# 2  1000   3        0.3    0.7571
# 3  1000   5        0.3    0.7511
# 4   200  10        0.3    0.6980
# 5   200   3        0.3    0.7495
# 6   200   5        0.3    0.7538
# 7    50  10        0.3    0.7101
# 8    50   3        0.3    0.7595
# 9    50   5        0.3    0.7422

# %%
dfC
# Out:
#     num   k  roughness  Accuracy
# 0  1000  10        0.3    0.3997
# 1  1000   3        0.3    0.3957
# 2  1000   5        0.3    0.3832
# 3   200  10        0.3    0.3902
# 4   200   3        0.3    0.4225
# 5   200   5        0.3    0.3976
# 6    50  10        0.3    0.4059
# 7    50   3        0.3    0.4222
# 8    50   5        0.3    0.4331
